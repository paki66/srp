# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# Američki nogomet podaci po svakoj akciji od 2009-2017 g. Podaci su iz National Football League (NFL) koji je najprofesionalniji rang igre. 350,000 Akcija ali sam ja ucitao samo prvih 2,000. Atributa za svaku akciju ima 102.

# %%
# Učitavanje potrebnih biblioteka
import pandas as pd

# Učitavanje podataka iz CSV datoteke
PATH = "NFL_dataset.csv"

# Učitavanje prvih 2000 redova
data = pd.read_csv(PATH, delimiter=',', nrows=2000)
pd.set_option('display.max_columns', None)

# Ispis prvih 5 redova
data.head()
# Out:
#          Date      GameID  Drive  qtr  down   time  TimeUnder  TimeSecs  \
# 0  2009-09-10  2009091000      1    1   NaN  15:00         15    3600.0
# 1  2009-09-10  2009091000      1    1   1.0  14:53         15    3593.0
# 2  2009-09-10  2009091000      1    1   2.0  14:16         15    3556.0
# 3  2009-09-10  2009091000      1    1   3.0  13:35         14    3515.0
# 4  2009-09-10  2009091000      1    1   4.0  13:27         14    3507.0
#
#    PlayTimeDiff SideofField  yrdln  yrdline100  ydstogo  ydsnet  GoalToGo  \
# 0             0         TEN   30.0        30.0        0       0       0.0
# 1             7         PIT   42.0        58.0       10       5       0.0
# 2            37         PIT   47.0        53.0        5       2       0.0
# 3            41         PIT   44.0        56.0        8       2       0.0
# 4             8         PIT   44.0        56.0        8       2       0.0
#
#    FirstDown posteam DefensiveTeam  \
# 0        NaN     PIT           TEN
# ...

# %%
print(data.shape)
# Out:
# (2000, 102)

# %%
data.isna().sum()
# Out:
# Date           0
# GameID         0
# Drive          0
# qtr            0
# down         297
#             ...
# Win_Prob     131
# WPA           29
# airWPA      1217
# yacWPA      1219
# Season         0
# Length: 102, dtype: int64

# %%
data.nunique()
# Out:
# Date           2
# GameID        12
# Drive         28
# qtr            5
# down           4
#             ...
# Win_Prob    1836
# WPA         1831
# airWPA       783
# yacWPA       693
# Season         1
# Length: 102, dtype: int64

# %%
data.dtypes
# Out:
# Date         object
# GameID        int64
# Drive         int64
# qtr           int64
# down        float64
#              ...
# Win_Prob    float64
# WPA         float64
# airWPA      float64
# yacWPA      float64
# Season        int64
# Length: 102, dtype: object

# %%
# Ispis broja jedinstvenih vrijednosti po stupcima
for column in data:
    print(data[column].value_counts())
    input("...")
# Out:
# Date
# 2009-09-13    1822
# 2009-09-10     178
# Name: count, dtype: int64
# GameID
# 2009091302    186
# 2009091309    184
# 2009091307    182
# 2009091301    182
# 2009091000    178
# 2009091304    172
# 2009091308    171
# 2009091305    163
# 2009091300    161
# 2009091306    161
# 2009091303    157
# 2009091311    103
# Name: count, dtype: int64
# Drive
# 4     122
# 1     107
# 11    104
# 10    102
# 9      97
# 19     96
# 15     90
# 20     90
# 5      85
# 21     81
# 7      81
# 12     81
# 18     78
# 2      77
# 8      74
# 6      74
# 13     72
# 16     70
# 3      67
# 14     67
# 17     66
# 22     66
# 24     50
# 25     37
# 26     23
# 27     22
# 23     19
# 28      2
# Name: count, dtype: int64
# qtr
# 2    577
# 4    512
# 1    455
# 3    444
# 5     12
# Name: count, dtype: int64
# down
# 1.0    665
# 2.0    515
# 3.0    342
# 4.0    181
# Name: count, dtype: int64
# time
# 15:00    56
# 00:00    40
# 02:00    34
# 00:38     9
# 14:52     8
#          ..
# ...

# %%
data.columns.values
# Out:
# array(['Date', 'GameID', 'Drive', 'qtr', 'down', 'time', 'TimeUnder',
#        'TimeSecs', 'PlayTimeDiff', 'SideofField', 'yrdln', 'yrdline100',
#        'ydstogo', 'ydsnet', 'GoalToGo', 'FirstDown', 'posteam',
#        'DefensiveTeam', 'desc', 'PlayAttempted', 'Yards.Gained', 'sp',
#        'Touchdown', 'ExPointResult', 'TwoPointConv', 'DefTwoPoint',
#        'Safety', 'Onsidekick', 'PuntResult', 'PlayType', 'Passer',
#        'Passer_ID', 'PassAttempt', 'PassOutcome', 'PassLength',
#        'AirYards', 'YardsAfterCatch', 'QBHit', 'PassLocation',
#        'InterceptionThrown', 'Interceptor', 'Rusher', 'Rusher_ID',
#        'RushAttempt', 'RunLocation', 'RunGap', 'Receiver', 'Receiver_ID',
#        'Reception', 'ReturnResult', 'Returner', 'BlockingPlayer',
#        'Tackler1', 'Tackler2', 'FieldGoalResult', 'FieldGoalDistance',
#        'Fumble', 'RecFumbTeam', 'RecFumbPlayer', 'Sack',
#        'Challenge.Replay', 'ChalReplayResult', 'Accepted.Penalty',
# ...
